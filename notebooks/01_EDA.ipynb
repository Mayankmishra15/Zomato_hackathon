# %% [markdown]
# # CSAO Dataset EDA

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Load csao_ml_final dataset
df = pd.read_csv('../csao_ml_final.csv')
df.head()

# %%
# Target distribution
px.pie(df, names=df['label'].map({0:'Rejected',1:'Accepted'}), title='Target Distribution')
