# %% [markdown]
# # Feature Engineering

# %%
import sys
sys.path.insert(0,'..')
from src.data_pipeline.preprocessor import load_and_split, engineer_features, build_pipeline

train_df, test_df = load_and_split()
train_df = engineer_features(train_df)
train_df.columns.tolist()
