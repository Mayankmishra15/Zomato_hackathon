# %% [markdown]
# # Business Impact Analysis

# %%
import sys
sys.path.insert(0,'..')
from src.evaluation.business_metrics import project_business_impact

project_business_impact(0.51, baseline_acceptance_rate=0.12, avg_item_price=120)
